# %% [markdown]
# <a href="https://colab.research.google.com/github/yoseflio/Practical-ML-Course-HW/blob/main/pandas_olympics_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
l = [12, 34, 5, 78]
[x+5 for x in l]
# Out:
# [17, 39, 10, 83]

# %%
ar = np.array(l)

# %%
type(ar)
# Out:
# numpy.ndarray

# %%
ar + 5
# Out:
# array([17, 39, 10, 83])

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 11.7,8.27

# %% [markdown]
# ## Loading data + Basic Pandas types
# 120 years of Olympic history: athletes and results
# basic bio data on athletes and medal results from Athens 1896 to Rio 2016
# https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results

# %%
df = pd.read_csv('https://storage.googleapis.com/valeria-edu-public-data/athlete_events.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
data = {
    'name': ['Sivan', 'Moshe', 'Dina'],
    'math': [76, 98, 99],
    'english': [89, 79, 100]
}

# %%
pd.DataFrame(data)
# Out:
#     name  math  english
# 0  Sivan    76       89
# 1  Moshe    98       79
# 2   Dina    99      100

# %%
series = pd.Series([1, 13, 14, 23], dtype=int, name='grades')

# %%
series
# Out:
# 0     1
# 1    13
# 2    14
# 3    23
# Name: grades, dtype: int64

# %% [markdown]
# ## Basic summary methods

# %%
df.head(10)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# ...

# %%
df.tail(7)
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 271109  135567  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
# 271111  135569                    Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                      Piotr ya   M  27.0   176.0    59.0
# 271113  135570                      Piotr ya   M  27.0   176.0    59.0
# 271114  135571            Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571            Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#             Team  NOC        Games  Year  Season            City        Sport  \
# 271109    Russia  RUS  2004 Summer  2004  Summer          Athina       Rowing
# 271110   Belarus  BLR  2016 Summer  2016  Summer  Rio de Janeiro   Basketball
# 271111  Poland-1  POL  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112    Poland  POL  2014 Winter  2014  Winter           Sochi  Ski Jumping
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
len(df)
# Out:
# 271116

# %% [markdown]
# ## Columns selection

# %%
df.head(3)
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0   1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN

# %%
# single column
df['Age']
# Out:
# 0         24.0
# 1         23.0
# 2         24.0
# 3         34.0
# 4         21.0
#           ...
# 271111    29.0
# 271112    27.0
# 271113    27.0
# 271114    30.0
# 271115    34.0
# Name: Age, Length: 271116, dtype: float64

# %%
df.Age

# %%
df[['Age','City']]
# Out:
#          Age            City
# 0       24.0       Barcelona
# 1       23.0          London
# 2       24.0       Antwerpen
# 3       34.0           Paris
# 4       21.0         Calgary
# ...      ...             ...
# 271111  29.0       Innsbruck
# 271112  27.0           Sochi
# 271113  27.0           Sochi
# 271114  30.0          Nagano
# 271115  34.0  Salt Lake City
#
# [271116 rows x 2 columns]

# %%
# not working
df['Age', 'City']

# %%
df['Age']
# Out:
# 0         24.0
# 1         23.0
# 2         24.0
# 3         34.0
# 4         21.0
#           ...
# 271111    29.0
# 271112    27.0
# 271113    27.0
# 271114    30.0
# 271115    34.0
# Name: Age, Length: 271116, dtype: float64

# %%
df[['Age']]
# Out:
#          Age
# 0       24.0
# 1       23.0
# 2       24.0
# 3       34.0
# 4       21.0
# ...      ...
# 271111  29.0
# 271112  27.0
# 271113  27.0
# 271114  30.0
# 271115  34.0
#
# [271116 rows x 1 columns]

# %%
# multiple columns

# %% [markdown]
# ## Index and Rows Selection

# %%
df.head(5)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df['Age']
# Out:
# 0         24.0
# 1         23.0
# 2         24.0
# 3         34.0
# 4         21.0
#           ...
# 271111    29.0
# 271112    27.0
# 271113    27.0
# 271114    30.0
# 271115    34.0
# Name: Age, Length: 271116, dtype: float64

# %%
df.loc[2]
# Out:
# ID                              3
# Name          Gunnar Nielsen Aaby
# Sex                             M
# Age                          24.0
# Height                        NaN
# Weight                        NaN
# Team                      Denmark
# NOC                           DEN
# Games                 1920 Summer
# Year                         1920
# Season                     Summer
# City                    Antwerpen
# Sport                    Football
# Event     Football Men's Football
# Medal                         NaN
# Name: 2, dtype: object

# %%
df.loc[2:20:4]
# Out:
#     ID                      Name Sex   Age  Height  Weight           Team  \
# 2    3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN        Denmark
# 6    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0    Netherlands
# 10   6           Per Knut Aaland   M  31.0   188.0    75.0  United States
# 14   6           Per Knut Aaland   M  33.0   188.0    75.0  United States
# 18   7              John Aalberg   M  31.0   183.0    72.0  United States
#
#     NOC        Games  Year  Season         City                 Sport  \
# 2   DEN  1920 Summer  1920  Summer    Antwerpen              Football
# 6   NED  1992 Winter  1992  Winter  Albertville         Speed Skating
# 10  USA  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 14  USA  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
# 18  USA  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
#
#                                        Event Medal
# ...

# %%
df.loc[20:2:-1]

# %%
df.head(5)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df1 = df.set_index('Name')

# %%
df.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
df.loc[[1,7]]
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 1   2                  A Lamusi   M  23.0   170.0    60.0        China  CHN
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 1  2012 Summer  2012  Summer       London           Judo
# 7  1992 Winter  1992  Winter  Albertville  Speed Skating
#
#                                 Event Medal
# 1        Judo Men's Extra-Lightweight   NaN
# 7  Speed Skating Women's 1,000 metres   NaN

# %%
df1.head(7)
# Out:
#                           ID Sex   Age  Height  Weight            Team  NOC  \
# Name
# A Dijiang                  1   M  24.0   180.0    80.0           China  CHN
# A Lamusi                   2   M  23.0   170.0    60.0           China  CHN
# Gunnar Nielsen Aaby        3   M  24.0     NaN     NaN         Denmark  DEN
# Edgar Lindenau Aabye       4   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# Christine Jacoba Aaftink   5   F  21.0   185.0    82.0     Netherlands  NED
# Christine Jacoba Aaftink   5   F  21.0   185.0    82.0     Netherlands  NED
# Christine Jacoba Aaftink   5   F  25.0   185.0    82.0     Netherlands  NED
#
#                                 Games  Year  Season         City  \
# Name
# A Dijiang                 1992 Summer  1992  Summer    Barcelona
# A Lamusi                  2012 Summer  2012  Summer       London
# Gunnar Nielsen Aaby       1920 Summer  1920  Summer    Antwerpen
# Edgar Lindenau Aabye      1900 Summer  1900  Summer        Paris
# ...

# %%
df1.loc['Christine Jacoba Aaftink']
# Out:
#                           ID Sex   Age  Height  Weight         Team  NOC  \
# Name
# Christine Jacoba Aaftink   5   F  21.0   185.0    82.0  Netherlands  NED
# Christine Jacoba Aaftink   5   F  21.0   185.0    82.0  Netherlands  NED
# Christine Jacoba Aaftink   5   F  25.0   185.0    82.0  Netherlands  NED
# Christine Jacoba Aaftink   5   F  25.0   185.0    82.0  Netherlands  NED
# Christine Jacoba Aaftink   5   F  27.0   185.0    82.0  Netherlands  NED
# Christine Jacoba Aaftink   5   F  27.0   185.0    82.0  Netherlands  NED
#
#                                 Games  Year  Season         City  \
# Name
# Christine Jacoba Aaftink  1988 Winter  1988  Winter      Calgary
# Christine Jacoba Aaftink  1988 Winter  1988  Winter      Calgary
# Christine Jacoba Aaftink  1992 Winter  1992  Winter  Albertville
# Christine Jacoba Aaftink  1992 Winter  1992  Winter  Albertville
# Christine Jacoba Aaftink  1994 Winter  1994  Winter  Lillehammer
# ...

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df.set_index(['City', 'Year']).loc['Athina']
# Out:
#           ID                              Name Sex   Age  Height  Weight  \
# Year
# 2004      23                       Fritz Aanes   M  26.0   187.0    89.0
# 2004      49                      Moonika Aava   F  24.0   168.0    65.0
# 2004      72  Aleksey Aleksandrovich Abalmasov   M  24.0   180.0    83.0
# 2004      75                    Giorgos Abalof   M  22.0   178.0    70.0
# 2004      81                   Georgios Abaris   M  22.0   190.0    77.0
# ...      ...                               ...  ..   ...     ...     ...
# 2004  135535         Claudia Antoinette Zwiers   F  30.0   181.0    78.0
# 2004  135560                 Stavroula Zygouri   F  36.0   171.0    63.0
# 2004  135563         Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
# 2004  135565          Fernando scar Zylberberg   M  27.0   168.0    76.0
# 2004  135567      Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
#
#              Team  NOC        Games  Season      Sport  \
# Year
# ...

# %%
df1
# Out:
#                             Name      ID Sex   Age  Height  Weight  \
# 0                      A Dijiang       1   M  24.0   180.0    80.0
# 1                       A Lamusi       2   M  23.0   170.0    60.0
# 2            Gunnar Nielsen Aaby       3   M  24.0     NaN     NaN
# 3           Edgar Lindenau Aabye       4   M  34.0     NaN     NaN
# 4       Christine Jacoba Aaftink       5   F  21.0   185.0    82.0
# ...                          ...     ...  ..   ...     ...     ...
# 271111                Andrzej ya  135569   M  29.0   179.0    89.0
# 271112                  Piotr ya  135570   M  27.0   176.0    59.0
# 271113                  Piotr ya  135570   M  27.0   176.0    59.0
# 271114        Tomasz Ireneusz ya  135571   M  30.0   185.0    96.0
# 271115        Tomasz Ireneusz ya  135571   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df1.reset_index(inplace=True)

# %%
# slicing and striding

# %%
# multiindex

# %%
df.loc[10:20, ['Age', 'Name']]
# Out:
#      Age             Name
# 10  31.0  Per Knut Aaland
# 11  31.0  Per Knut Aaland
# 12  31.0  Per Knut Aaland
# 13  31.0  Per Knut Aaland
# 14  33.0  Per Knut Aaland
# 15  33.0  Per Knut Aaland
# 16  33.0  Per Knut Aaland
# 17  33.0  Per Knut Aaland
# 18  31.0     John Aalberg
# 19  31.0     John Aalberg
# 20  31.0     John Aalberg

# %%
df.loc[10:20, :]
# Out:
#     ID             Name Sex   Age  Height  Weight           Team  NOC  \
# 10   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 11   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 12   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 13   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 14   6  Per Knut Aaland   M  33.0   188.0    75.0  United States  USA
# 15   6  Per Knut Aaland   M  33.0   188.0    75.0  United States  USA
# 16   6  Per Knut Aaland   M  33.0   188.0    75.0  United States  USA
# 17   6  Per Knut Aaland   M  33.0   188.0    75.0  United States  USA
# 18   7     John Aalberg   M  31.0   183.0    72.0  United States  USA
# 19   7     John Aalberg   M  31.0   183.0    72.0  United States  USA
# 20   7     John Aalberg   M  31.0   183.0    72.0  United States  USA
#
#           Games  Year  Season         City                 Sport  \
# ...

# %%
df = df.set_index('Name')

# %%
df
# Out:
#                               ID Sex   Age  Height  Weight            Team  \
# Name
# A Dijiang                      1   M  24.0   180.0    80.0           China
# A Lamusi                       2   M  23.0   170.0    60.0           China
# Gunnar Nielsen Aaby            3   M  24.0     NaN     NaN         Denmark
# Edgar Lindenau Aabye           4   M  34.0     NaN     NaN  Denmark/Sweden
# Christine Jacoba Aaftink       5   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# Andrzej ya                135569   M  29.0   179.0    89.0        Poland-1
# Piotr ya                  135570   M  27.0   176.0    59.0          Poland
# Piotr ya                  135570   M  27.0   176.0    59.0          Poland
# Tomasz Ireneusz ya        135571   M  30.0   185.0    96.0          Poland
# Tomasz Ireneusz ya        135571   M  34.0   185.0    96.0          Poland
#
# ...

# %%
df.iloc[-10:]

# %% [markdown]
# ## Copy

# %%
my_df = df.copy(deep=True)

# %% [markdown]
# ## Masks and filter

# %%
df['Age']

# %%
# simple, & |
df['Age'] + 5

# %%
df[['Age', 'Weight', 'Height']]

# %%
df[['Age', 'Weight', 'Height']] + 100

# %%
df['Age'] == 10
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Age, Length: 271116, dtype: bool

# %%
df[['Height', 'Weight']] == 100

# %%
df[df['Age'] == 10]
# Out:
#            ID                Name Sex   Age  Height  Weight  \
# 142882  71691  Dimitrios Loundras   M  10.0     NaN     NaN
#
#                                  Team  NOC        Games  Year  Season    City  \
# 142882  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896  Summer  Athina
#
#              Sport                                  Event   Medal
# 142882  Gymnastics  Gymnastics Men's Parallel Bars, Teams  Bronze

# %%
df[(df['Age'] < 16) & (df['NOC'] == 'USA')].count()
# Out:
# ID        208
# Name      208
# Sex       208
# Age       208
# Height    181
# Weight    175
# Team      208
# NOC       208
# Games     208
# Year      208
# Season    208
# City      208
# Sport     208
# Event     208
# Medal      76
# dtype: int64

# %%
df[(df['Age'] < 16) & (df['NOC'] == 'USA')]['ID'].count()
# Out:
# 208

# %%
df[(df['Age'] < 16) & (df['NOC'] == 'USA')]['City'].unique()
# Out:
# array(['Paris', 'Innsbruck', 'Tokyo', 'Mexico City', 'Munich', 'Atlanta',
#        'Beijing', 'Los Angeles', 'Montreal', 'Sapporo', 'Berlin',
#        'Barcelona', 'Roma', 'Lake Placid', 'Sankt Moritz', 'Sochi',
#        'Melbourne', 'Amsterdam', 'Athina', 'Helsinki', 'Seoul', 'Nagano',
#        'Albertville', 'London', 'Grenoble', 'Antwerpen', 'St. Louis',
#        'Squaw Valley', 'Sydney'], dtype=object)

# %%
df[(df['Age'] < 16) & (df['NOC'] == 'USA')]['City'].nunique()
# Out:
# 29

# %%
df[(df['Age'] < 16) & (df['NOC'] == 'USA')].nunique()
# Out:
# ID        105
# Name      105
# Sex         2
# Age         4
# Height     29
# Weight     34
# Team       11
# NOC         1
# Games      33
# Year       26
# Season      2
# City       29
# Sport      15
# Event      59
# Medal       3
# dtype: int64

# %% [markdown]
# ## Column addition

# %%
df['Is_Child'] = df['Age'] <= 16

# %%
#df['person_type'] = 'child' if df['Age'] <= 16 else 'old'

# %%
'child' if df['Age'] <= 16 else 'old'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-188-0bf17dd6fdd6> in <module>()
# ----> 1 'child' if df['Age'] <= 16 else 'old'
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1536     def __nonzero__(self):
#    1537         raise ValueError(
# -> 1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
bool(df['Age'].values <= 16)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-194-2810cbf4786f> in <module>()
# ----> 1 bool(df['Age'].values <= 16)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
df.head(5)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal  Is_Child
# 0       Basketball Men's Basketball   NaN     False
# 1      Judo Men's Extra-Lightweight   NaN     False
# ...

# %% [markdown]
# ## Column deletion

# %%
# del
# pop
# drop - both columns and rows
df.drop(columns=['Is_Child'], inplace=True)

# %% [markdown]
# ## Columns update

# %%
#astype
# df['Sex'] = 'Female' if df['Sex'] == 'F' else 'Male'
df.dropna(inplace=True)
new_age = df['Age'].astype(int)

# %%
df['Age'] = new_age

# %%
df

# %% [markdown]
# ## Rename Columns and Indices

# %%
# df.rename(columns={'City':'city'})
# df.rename({0: '000'})

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
{col: col.lower() for col in df.columns}
# Out:
# {'Age': 'age',
#  'City': 'city',
#  'Event': 'event',
#  'Games': 'games',
#  'Height': 'height',
#  'ID': 'id',
#  'Medal': 'medal',
#  'NOC': 'noc',
#  'Name': 'name',
#  'Season': 'season',
#  'Sex': 'sex',
#  'Sport': 'sport',
#  'Team': 'team',
#  'Weight': 'weight',
#  'Year': 'year'}

# %%
df.rename(columns={col: col.lower() for col in df.columns})

# %%
df.rename({0: '000', 1:'111'})

# %% [markdown]
# ## Useful methods

# %%
# count
# sum
# unique
# nunique
# value_counts(normalize)

# %%
df['ID'].value_counts()
# Out:
# 106296    39
# 115354    38
# 129196    32
# 89187     32
# 106156    31
#           ..
# 78942      1
# 30875      1
# 30881      1
# 78935      1
# 1          1
# Name: ID, Length: 129203, dtype: int64

# %%
df['ID'].value_counts(normalize=True)
# Out:
# 106296    0.000150
# 115354    0.000146
# 129196    0.000123
# 89187     0.000123
# 106156    0.000119
#             ...
# 78942     0.000004
# 30875     0.000004
# 30881     0.000004
# 78935     0.000004
# 1         0.000004
# Name: ID, Length: 129203, dtype: float64

# %%
df['City'].value_counts(normalize=True)

# %%
df['Sex'].value_counts(normalize=True)
# Out:
# M    0.715931
# F    0.284069
# Name: Sex, dtype: float64

# %%
df[df['ID'] == 106296]

# %% [markdown]
# ### query() method

# %%
# df[(df['Age'] > 30) & (df['Weight']<80)]
# df.query('Age > 30 and Weight < 80')

# col name with space - use backticks
# df1 = df.rename(columns={'Weight': 'Athlete weight'})
# df1
# df1.query('`Athlete weight` > 90')

# variables - use @
weight = 90
df1.query('`Athlete weight` > @weight')

# %% [markdown]
# ### apply() method

# %%
df1 = df[:10][['Name', 'Event', 'Medal']]

# %%
df1
# Out:
#                        Name                               Event     Medal
# 0                 A Dijiang         Basketball Men's Basketball  No medal
# 1                  A Lamusi        Judo Men's Extra-Lightweight  No medal
# 2       Gunnar Nielsen Aaby             Football Men's Football  No medal
# 3      Edgar Lindenau Aabye         Tug-Of-War Men's Tug-Of-War      Gold
# 4  Christine Jacoba Aaftink    Speed Skating Women's 500 metres  No medal
# 5  Christine Jacoba Aaftink  Speed Skating Women's 1,000 metres  No medal
# 6  Christine Jacoba Aaftink    Speed Skating Women's 500 metres  No medal
# 7  Christine Jacoba Aaftink  Speed Skating Women's 1,000 metres  No medal
# 8  Christine Jacoba Aaftink    Speed Skating Women's 500 metres  No medal
# 9  Christine Jacoba Aaftink  Speed Skating Women's 1,000 metres  No medal

# %%
# df[['Age']].apply(lambda col: 'child' if col<=16 else 'old')

# %%
df1.apply(lambda col: col.str.lower()) #default axis = 0, a.k.a working on columns

# %%
df1.apply(lambda col: col.name + ": " + col.str.lower()) #default axis = 0, a.k.a working on columns
# Out:
#                              Name                                      Event  \
# 0                 Name: a dijiang         Event: basketball men's basketball
# 1                  Name: a lamusi        Event: judo men's extra-lightweight
# 2       Name: gunnar nielsen aaby             Event: football men's football
# 3      Name: edgar lindenau aabye         Event: tug-of-war men's tug-of-war
# 4  Name: christine jacoba aaftink    Event: speed skating women's 500 metres
# 5  Name: christine jacoba aaftink  Event: speed skating women's 1,000 metres
# 6  Name: christine jacoba aaftink    Event: speed skating women's 500 metres
# 7  Name: christine jacoba aaftink  Event: speed skating women's 1,000 metres
# 8  Name: christine jacoba aaftink    Event: speed skating women's 500 metres
# 9  Name: christine jacoba aaftink  Event: speed skating women's 1,000 metres
#
#              Medal
# 0  Medal: no medal
# 1  Medal: no medal
# 2  Medal: no medal
# 3      Medal: gold
# 4  Medal: no medal
# ...

# %%
name = "Valeria"
medal = "Gold"
name + " won a " +medal +" medal"
# Out:
# 'Valeria won a Gold medal'

# %%
f"{name} won a {medal} medal {medal =='Gold'}"
# Out:
# 'Valeria won a Gold medal True'

# %%
df1.apply(
    lambda row: f"Athlete {row['Name']} won {row['Medal']}" if row['Medal'] != 'No medal' else f"Athlete {row['Name']} didn't win any medal", 
    axis=1) # working on rows
# Out:
# 0               Athlete A Dijiang didn't win any medal
# 1                Athlete A Lamusi didn't win any medal
# 2     Athlete Gunnar Nielsen Aaby didn't win any medal
# 3                Athlete Edgar Lindenau Aabye won Gold
# 4    Athlete Christine Jacoba Aaftink didn't win an...
# 5    Athlete Christine Jacoba Aaftink didn't win an...
# 6    Athlete Christine Jacoba Aaftink didn't win an...
# 7    Athlete Christine Jacoba Aaftink didn't win an...
# 8    Athlete Christine Jacoba Aaftink didn't win an...
# 9    Athlete Christine Jacoba Aaftink didn't win an...
# dtype: object

# %%
def cut_by_age(age):
  if age <=16:
    return 'child'
  elif age <= 25:
    return 'adult'
  else:
    return 'old'

# %%
df[['Age']].applymap(cut_by_age)
# Out:
#           Age
# 0       adult
# 1       adult
# 2       adult
# 3         old
# 4       adult
# ...       ...
# 271111    old
# 271112    old
# 271113    old
# 271114    old
# 271115    old
#
# [271116 rows x 1 columns]

# %%
df[['Age']].applymap(lambda age: 'child' if age <=16 else 'old')
# Out:
#         Age
# 0       old
# 1       old
# 2       old
# 3       old
# 4       old
# ...     ...
# 271111  old
# 271112  old
# 271113  old
# 271114  old
# 271115  old
#
# [271116 rows x 1 columns]

# %%
df1.loc[0]['Medal']
# Out:
# nan

# %%
df = athlete_events[:10]
df
# df.apply(lambda row: row.str.lower()) # will raise an error
# fix here
df.apply(lambda col: col.str.lower() if col.dtype == 'O' else col)

# %%
df.apply(lambda col: col.fillna('None').str.lower() if col.dtype == 'O' else col.fillna(0).astype(np.int32)) # will raise an error
# fix here

# %% [markdown]
# ## Cut

# %%
pd.cut(df['Age'], bins=3)
# Out:
# 0         (9.913, 39.0]
# 1         (9.913, 39.0]
# 2         (9.913, 39.0]
# 3         (9.913, 39.0]
# 4         (9.913, 39.0]
#               ...
# 271111    (9.913, 39.0]
# 271112    (9.913, 39.0]
# 271113    (9.913, 39.0]
# 271114    (9.913, 39.0]
# 271115    (9.913, 39.0]
# Name: Age, Length: 271116, dtype: category
# Categories (3, interval[float64, right]): [(9.913, 39.0] < (39.0, 68.0] < (68.0, 97.0]]

# %%
pd.cut(df['Age'], bins=[0, 16, 25, 50, 97])
# Out:
# 0         (16, 25]
# 1         (16, 25]
# 2         (16, 25]
# 3         (25, 50]
# 4         (16, 25]
#             ...
# 271111    (25, 50]
# 271112    (25, 50]
# 271113    (25, 50]
# 271114    (25, 50]
# 271115    (25, 50]
# Name: Age, Length: 271116, dtype: category
# Categories (4, interval[int64, right]): [(0, 16] < (16, 25] < (25, 50] < (50, 97]]

# %% [markdown]
# ## Sort

# %%
# sort_values vs sort_index
# df.sort_values(ascending=False)
# df.sort_values(['City', 'Sport'])

# %%
df.sort_values('Age')

# %%
df.sort_values('Age', ascending=False)

# %%
df.dropna(subset=['Height']).sort_values(['Age', 'Height'], ascending=False)

# %%
df.set_index('Name').sort_index()
# Out:
#                                                ID Sex   Age  Height  Weight  \
# Name
#   Gabrielle Marie "Gabby" Adcock (White-)     869   F  25.0   167.0     NaN
#  Eleonora Margarida Josephina Scmitt       107953   F  16.0     NaN     NaN
#  Eleonora Margarida Josephina Scmitt       107953   F  16.0     NaN     NaN
#  Jean Hauptmanns                            46661   M  26.0     NaN     NaN
#  Luis ngel Fernando de los Santos Grossi    26388   M  23.0     NaN     NaN
# ...                                           ...  ..   ...     ...     ...
# zlem Kaya                                   58232   F  26.0   165.0    47.0
# zman Graud                                  40545   M  33.0   168.0    72.0
# zzet Safer                                 104222   M  26.0   178.0    74.0
# zzet nce                                    52087   M  23.0   172.0    85.0
# zzet nce                                    52087   M  27.0   172.0    85.0
#
# ...

# %% [markdown]
# ## Handling nans

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df['Age'].isna().any()
# Out:
# True

# %%
df['Age'].isna().sum()
# Out:
# 9474

# %%
df.isna()
# Out:
#            ID   Name    Sex    Age  Height  Weight   Team    NOC  Games  \
# 0       False  False  False  False   False   False  False  False  False
# 1       False  False  False  False   False   False  False  False  False
# 2       False  False  False  False    True    True  False  False  False
# 3       False  False  False  False    True    True  False  False  False
# 4       False  False  False  False   False   False  False  False  False
# ...       ...    ...    ...    ...     ...     ...    ...    ...    ...
# 271111  False  False  False  False   False   False  False  False  False
# 271112  False  False  False  False   False   False  False  False  False
# 271113  False  False  False  False   False   False  False  False  False
# 271114  False  False  False  False   False   False  False  False  False
# 271115  False  False  False  False   False   False  False  False  False
#
#          Year  Season   City  Sport  Event  Medal
# 0       False   False  False  False  False   True
# ...

# %%
df.fillna({'Medal': 'No medal'}, inplace=True)

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event     Medal
# 0       Basketball Men's Basketball  No medal
# 1      Judo Men's Extra-Lightweight  No medal
# ...

# %%
df['Height'].mean()
# Out:
# 175.33896987366376

# %%
df.fillna({'Height': df['Height'].mean(), 'Weight': df['Weight'].mean()}, inplace=True)

# %%
df['Height'] = df['Height'].fillna(df['Height'].mean())

# %%
df1 = pd.read_csv('https://storage.googleapis.com/valeria-edu-public-data/athlete_events.csv')

# %%
len(df1)
# Out:
# 271116

# %%
len(df1.dropna())
# Out:
# 30181

# %%
df = df.dropna(subset=['Age'])

# %%
df.isna().any()
# Out:
# ID        False
# Name      False
# Sex       False
# Age       False
# Height    False
# Weight    False
# Team      False
# NOC       False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal     False
# dtype: bool

# %%
df1.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
cols_with_nans = df1.isna().sum()[df1.isna().sum() > 50000].index

# %%
df1.dropna(subset=cols_with_nans)
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 40          16             Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 42          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271082  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
# ...

# %% [markdown]
# ## Handling duplicates

# %%
df.duplicated().sum()
# Out:
# 1226

# %%
df[df.duplicated(keep=False)]

# %%
len(df)
# Out:
# 261642

# %%
df.drop_duplicates(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
len(df)
# Out:
# 260416

# %%
df.duplicated(subset=['ID', 'Year', 'Season', 'Event']).sum()
# Out:
# 68

# %%
df[df.duplicated(subset=['ID', 'Year', 'Season', 'Event'], keep=False)]
# Out:
#             ID                                       Name Sex   Age  \
# 10910     5959  Louis Albert Auguste-Dormeuil (Dormeuil-)   M  31.0
# 10911     5959  Louis Albert Auguste-Dormeuil (Dormeuil-)   M  31.0
# 16116     8683                           Jacques Baudrier   M  28.0
# 16117     8683                           Jacques Baudrier   M  28.0
# 16118     8683                           Jacques Baudrier   M  28.0
# ...        ...                                        ...  ..   ...
# 252687  126533      Franois Antoine Vilamitjana (Caubet-)   M  53.0
# 258101  129244                        mile Robert Wegelin   M  24.0
# 258102  129244                        mile Robert Wegelin   M  24.0
# 265263  132751                          Jack Butler Yeats   M  52.0
# 265264  132751                          Jack Butler Yeats   M  52.0
#
#            Height     Weight                     Team  NOC        Games  Year  \
# ...

# %%
# df.duplicated()
# df[df.duplicated()]
# df.duplicated().sum()
# print(f"before drop: {len(athlete_events)}")
# df_new = df.drop_duplicates()
# df.duplicated(subset=['ID']).any()
# df.duplicated(subset=['ID']).sum()
# df[df.duplicated(subset=['ID', 'Sport'])]
# df[df.duplicated(subset=['Name', 'ID', 'Event', 'Year'])]

# %% [markdown]
# ## Group by

# %%
# group by single column
grouped =df[['ID', 'Medal']].groupby('Medal')
print(f"Type: {type(grouped)}\nObj: {grouped}")
# Out:
# Type: <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# Obj: <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7feb1121ea50>

# %%
grouped.count()
# Out:
#            ID
# Medal
# Bronze  13295
# Gold    13372
# Silver  13116

# %%
df[['ID', 'Medal']].groupby('Medal').count()
# Out:
#            ID
# Medal
# Bronze  13295
# Gold    13372
# Silver  13116

# %%
df[['Sex', 'Height', 'Weight', 'Age']].groupby('Sex').mean()
# Out:
#          Height     Weight        Age
# Sex
# F    167.839740  60.021252  23.732881
# M    178.858463  75.743677  26.277562

# %%
df[['Sex', 'Height', 'Weight', 'Age']].groupby('Sex').min()
# Out:
#      Height  Weight   Age
# Sex
# F     127.0    25.0  11.0
# M     127.0    28.0  10.0

# %%
# grouped_df = grouped.count()
# print(f"Type: {type(grouped_df)}\nObj: {grouped_df}")

# grouped_s = athlete_events.groupby('Medal').count().ID
# print(f"Type: {type(grouped_s)}\nObj: {grouped_s}")

# groups = grouped.groups
# print(f"Type: {type(groups)}\nObj: {groups}")
# print(grouped.groups.keys())

# iterate groups
# for name, group in grouped:
#   print(name)
#   print(group)
#   print(group['Name'])

# get group by name
# grouped.get_group("Bronze")

# more nice options
# grouped.size()
# grouped.ID.describe()

# show unique sport per year
# unique_sport_per_year = df.groupby(['Year']).Sport.unique()
# # print(f"{type(unique_sport_per_year)}")
# # print(unique_sport_per_year)
# print(f"Sports at Olympics 1896: {unique_sport_per_year.loc[1896]}")
# print(f"Sports at Olympics 1900: {unique_sport_per_year.loc[1900]}")
# Out:
# Type: <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# Obj: <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7feb0ff73850>
# Sports at Olympics 1896: ['Tennis' 'Athletics' 'Swimming' 'Gymnastics' 'Shooting' 'Cycling'
#  'Fencing' 'Weightlifting' 'Wrestling']
# Sports at Olympics 1900: ['Tug-Of-War' 'Gymnastics' 'Golf' 'Rowing' 'Fencing' 'Swimming' 'Shooting'
#  'Rugby' 'Sailing' 'Football' 'Cycling' 'Athletics' 'Cricket' 'Water Polo'
#  'Equestrianism' 'Croquet' 'Archery' 'Polo' 'Tennis' 'Basque Pelota']

# %% [markdown]
# ### Group by: Applying multiple functions at once

# %%
df[['Sex', 'Height', 'Weight', 'Age']].groupby('Sex').agg([np.mean, 'max', lambda x: x.nunique()])
# Out:
#          Height                       Weight                          Age  \
#            mean    max <lambda_0>       mean    max <lambda_0>       mean
# Sex
# F    167.839740  213.0         77  60.021252  167.0        140  23.732881
# M    178.858463  226.0         92  75.743677  214.0        206  26.277562
#
#
#       max <lambda_0>
# Sex
# F    74.0         62
# M    97.0         74

# %%
df.groupby(['Year'])['Weight'].agg([np.sum, np.mean, np.std, np.min, np.max, 'max'])

# %%
df.groupby(['Year'])['Name'].agg(['min', lambda x: len(x.unique()), 'count'])

# %% [markdown]
# ### Group by: Applying different functions to DataFrame columns

# %%
df.reset_index(inplace=True)

# %%
grouped = df[['Sex', 'Name', 'Weight', 'Age']].groupby('Sex')
grouped.agg({"Age": np.mean, 'Name': pd.Series.nunique, 'Weight': np.max})
# aggregated_df = grouped_by_year.agg({"Age": [np.mean, np.min, np.max], "Name": pd.Series.nunique})
# aggregated_df
# create df that stores per year and season: total amount of events, total amount of athlets, avg/min/max weight, height, age of athlets
# Out:
#            Age    Name  Weight
# Sex
# F    23.732881   33808   167.0
# M    26.277562  100979   214.0

# %% [markdown]
# ## Working with texts

# %%
df['Name']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-239-1b28e6180325> in <module>()
# ----> 1 df['Name'].lower()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
df['Name'].str

# %%
df['Name'].str.lower()
# Out:
# 0                        a dijiang
# 1                         a lamusi
# 2              gunnar nielsen aaby
# 3             edgar lindenau aabye
# 4         christine jacoba aaftink
#                     ...
# 271111                  andrzej ya
# 271112                    piotr ya
# 271113                    piotr ya
# 271114          tomasz ireneusz ya
# 271115          tomasz ireneusz ya
# Name: Name, Length: 271116, dtype: object

# %%
df['Name'].str.contains('r')
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4          True
#           ...
# 271111     True
# 271112     True
# 271113     True
# 271114     True
# 271115     True
# Name: Name, Length: 271116, dtype: bool

# %%
df['Name']
# Out:
# 0                        A Dijiang
# 1                         A Lamusi
# 2              Gunnar Nielsen Aaby
# 3             Edgar Lindenau Aabye
# 4         Christine Jacoba Aaftink
#                     ...
# 271111                  Andrzej ya
# 271112                    Piotr ya
# 271113                    Piotr ya
# 271114          Tomasz Ireneusz ya
# 271115          Tomasz Ireneusz ya
# Name: Name, Length: 271116, dtype: object

# %%
df['Name'].str.split(" ")
# Out:
# 0                         [A, Dijiang]
# 1                          [A, Lamusi]
# 2              [Gunnar, Nielsen, Aaby]
# 3             [Edgar, Lindenau, Aabye]
# 4         [Christine, Jacoba, Aaftink]
#                       ...
# 271111                   [Andrzej, ya]
# 271112                     [Piotr, ya]
# 271113                     [Piotr, ya]
# 271114          [Tomasz, Ireneusz, ya]
# 271115          [Tomasz, Ireneusz, ya]
# Name: Name, Length: 271116, dtype: object

# %%
df['Name'].str.split(" ").str.get(0).str.lower()
# Out:
# 0                 a
# 1                 a
# 2            gunnar
# 3             edgar
# 4         christine
#             ...
# 271111      andrzej
# 271112        piotr
# 271113        piotr
# 271114       tomasz
# 271115       tomasz
# Name: Name, Length: 271116, dtype: object

# %%
df['Name'].str.split(" ").str.get(1).str.lower()

# %%
# reminder of python sorted()

l = ['a','c','b']
sorted(l)

# take the second element for sort
def take_second(elem):
    return elem[1]


# random list
random = [(2, 2), (3, 4), (4, 1), (1, 3)]

# sort list with key
sorted_list = sorted(random, key=take_second)

# print list
print('Sorted list:', sorted_list)

# back to Pandas
# sort_values vs sort_index
#DataFrame.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False, key=None)

# athlete_events.sort_values(by='Name')[20:50]
# athlete_events.sort_values(by='Name', key=lambda name_col: name_col.str.lower())[20:50]
# athlete_events.sort_values(by='Name', key=lambda name_col: name_col.str.split().str.get(1))[20:50]

df = athlete_events.set_index(['Sport', 'ID'])
# df
df.sort_index()
df.sort_index(level=0)
df.sort_index(level=1)

# %% [markdown]
# ## Working with dates

# %%
ibm_stocks_data = 'https://storage.googleapis.com/valeria-edu-public-data/IBM_2006-01-01_to_2018-01-01.csv'
aapl_stocks_data = "https://storage.googleapis.com/valeria-edu-public-data/AAPL.csv.zip"

# %%
adf = pd.read_csv(aapl_stocks_data)

# %%
adf.head()
# Out:
#          Date       Low      Open     Volume      High     Close  \
# 0  12-12-1980  0.128348  0.128348  469033600  0.128906  0.128348
# 1  15-12-1980  0.121652  0.122210  175884800  0.122210  0.121652
# 2  16-12-1980  0.112723  0.113281  105728000  0.113281  0.112723
# 3  17-12-1980  0.115513  0.115513   86441600  0.116071  0.115513
# 4  18-12-1980  0.118862  0.118862   73449600  0.119420  0.118862
#
#    Adjusted Close
# 0        0.100453
# 1        0.095213
# 2        0.088224
# 3        0.090408
# 4        0.093029

# %%
adf.info()

# %%
pd.to_datetime(adf['Date'], dayfirst=True)
# Out:
# 0       1980-12-12
# 1       1980-12-15
# 2       1980-12-16
# 3       1980-12-17
# 4       1980-12-18
#            ...
# 10366   2022-01-24
# 10367   2022-01-25
# 10368   2022-01-26
# 10369   2022-01-27
# 10370   2022-01-28
# Name: Date, Length: 10371, dtype: datetime64[ns]

# %%
aapl = pd.read_csv(aapl_stocks_data, index_col='Date', parse_dates=['Date'], dayfirst=True)

# %%
aapl
# Out:
#                    Low        Open     Volume        High       Close  \
# Date
# 1980-12-12    0.128348    0.128348  469033600    0.128906    0.128348
# 1980-12-15    0.121652    0.122210  175884800    0.122210    0.121652
# 1980-12-16    0.112723    0.113281  105728000    0.113281    0.112723
# 1980-12-17    0.115513    0.115513   86441600    0.116071    0.115513
# 1980-12-18    0.118862    0.118862   73449600    0.119420    0.118862
# ...                ...         ...        ...         ...         ...
# 2022-01-24  154.699997  160.020004  162706700  162.300003  161.619995
# 2022-01-25  157.020004  158.979996  115798400  162.759995  159.779999
# 2022-01-26  157.820007  163.500000  108275300  164.389999  159.690002
# 2022-01-27  158.279999  162.449997  116691400  163.839996  159.220001
# 2022-01-28  162.800003  165.710007  179485800  170.350006  170.330002
#
#             Adjusted Close
# Date
# 1980-12-12        0.100453
# 1980-12-15        0.095213
# 1980-12-16        0.088224
# ...

# %%
aapl.index
# Out:
# DatetimeIndex(['1980-12-12', '1980-12-15', '1980-12-16', '1980-12-17',
#                '1980-12-18', '1980-12-19', '1980-12-22', '1980-12-23',
#                '1980-12-24', '1980-12-26',
#                ...
#                '2022-01-14', '2022-01-18', '2022-01-19', '2022-01-20',
#                '2022-01-21', '2022-01-24', '2022-01-25', '2022-01-26',
#                '2022-01-27', '2022-01-28'],
#               dtype='datetime64[ns]', name='Date', length=10371, freq=None)

# %%
aapl.loc['2020-03':'2020-5']
# Out:
#                   Low       Open     Volume       High      Close  \
# Date
# 2020-03-02  69.430000  70.570000  341397200  75.360001  74.702499
# 2020-03-03  71.449997  75.917503  319475600  76.000000  72.330002
# 2020-03-04  73.282501  74.110001  219178400  75.849998  75.684998
# 2020-03-05  72.852501  73.879997  187572800  74.887497  73.230003
# 2020-03-06  70.307503  70.500000  226176800  72.705002  72.257500
# ...               ...        ...        ...        ...        ...
# 2020-05-22  78.837502  78.942497   81803200  79.807503  79.722504
# 2020-05-26  79.125000  80.875000  125522000  81.059998  79.182503
# 2020-05-27  78.272499  79.035004  112945200  79.677498  79.527496
# 2020-05-28  78.907501  79.192497  133560800  80.860001  79.562500
# 2020-05-29  79.117500  79.812500  153532400  80.287498  79.485001
#
#             Adjusted Close
# Date
# 2020-03-02       73.783791
# 2020-03-03       71.440483
# 2020-03-04       74.754211
# 2020-03-05       72.329414
# ...

# %%
# ts = pd.to_datetime(dates, dayfirst=True)
# pd.read_csv(data_path, index_col='Date', parse_dates=['Date'], dayfirst=dayfirst).dropna()

# %%
# .dt property

# %%
aapl.reset_index()['Date'].dt.weekday
# Out:
# 0        4
# 1        0
# 2        1
# 3        2
# 4        3
#         ..
# 10366    0
# 10367    1
# 10368    2
# 10369    3
# 10370    4
# Name: Date, Length: 10371, dtype: int64

# %% [markdown]
# ## Plotting with matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4,5], [2, 3, 6, 8, 10], 'g*',
         [2, 4, 6, 8, 10, 12], [10, 11, 9, 7, 2, 4], 'bo')
plt.plot([1,2,3,4,5], [10,11,12,13,14])
# plt.show()

# %%
fig, axs = plt.subplots(1,2, figsize=[15, 8])
axs[0].hist(df[df.Sex == 'F']['Height'], bins=50)
axs[0].title.set_text('Female height distribution')
axs[1].hist(df[df.Sex == 'M']['Height'], bins=50)
axs[1].title.set_text('Male height distribution')
plt.show()

# %% [markdown]
# ## Plotting with seaborn

# %%
import seaborn as sns

# %%
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 20.7,10.27

# %%
sns.lineplot(data=aapl, x='Date', y='Close')

# %%
sns.scatterplot(data=df, x='Weight', y='Height')

# %%
sns.scatterplot(data=df, x='Weight', y='Height', hue='Sex')

# %%
# figure size in inches
rcParams['figure.figsize'] = 15.7,15.27
sns.displot(data=df, x='Height', height=10)

# %%
# some simple examples
# unique_athlets_per_year = athlete_events.drop_duplicates(subset=['ID', 'Year'])
# df = unique_athlets_per_year
# df
# histogram
# sns.histplot(df['Height'])
# sns.histplot(data=df, x='Height', y='Weight')

# scatter
# sns.scatterplot(df, x='Height') # error
# sns.scatterplot(data=df, x="Height", y="Weight")
# sns.scatterplot(data=df, x="Height", y="Medal")
# displaying 3 dimensions
# sns.scatterplot(data=df, x="Height", y="Weight", hue="Sex")
# 4 dimensions
# sns.scatterplot(data=df, x="Height", y="Weight", hue="Sex", size="Medal")

# categorical
df1 = df.query('2000 <= Year <= 2020').groupby(['Year','Sex']).count()
df1
df1.reset_index(inplace=True) #note usage of reset_index()
df1
sns.barplot(data=df1, x='Year', y='ID', hue='Sex')

# %%
# Figure vs Axes plots
# https://seaborn.pydata.org/tutorial/function_overview.html

unique_athlets = athlete_events.drop_duplicates(subset=['ID'])

# setting figure size
# for Axes plot:
# fig, ax = plt.subplots(figsize=[12,8])
# ax.set_xlabel("Athlete height")
# sns.histplot(df, x='Height', ax=ax)


# for Figure plots
sns.displot(unique_athlets, x='Height', height=8, kind='hist')
g = sns.displot(unique_athlets, x='Height', height=8, kind='kde')
g.set_axis_labels("Athlets height", "Density")

# %%
# Distribution of  athlets' age

plt.hist(df["Age"], bins=50)
# # change bins
plt.title('Distribution of athlets age')
plt.xlabel('Age')
plt.ylabel('Number of athlets')
plt.show()

# %%
sns.histplot(data=df, x='Age', bins=100, binwidth=1)

# %%
# plotting with pandas
df.Age.hist()

# %%
# calculating mean/median/mode
# age_df = athlete_events.Age
# athlete_events["Age"]
print(f"Avg: {df['Age'].mean()}\nMedian: {sd['Age'].median()}\nMode: {sd.Age.mode()}")

# %%
# display graph of amount of unique sports per year
unique_sport_per_year = df.groupby(['Year']).Sport.nunique()
unique_sport_per_year
unique_sport_per_year.plot.bar(figsize=[12,8])
# Q: what hapenned after 1992?

# %%
g = sns.FacetGrid(df, col="Sex", height=10)
g.map(sns.histplot, "Height")

# %% [markdown]
# ## More data analysis

# %%
# Which city hosted most Olympic games?
df.groupby(['City'])['Year'].nunique().idxmax()
df.groupby(['City'])['Year'].nunique().max()
df.groupby(['City'])['Year'].nunique()

# %%
# how can we handle the data?
# display separately for winter/summer
# unique_sports_summer = athlete_events[athlete_events['Season'] == 'Summer'].groupby(['Year']).Sport.nunique() # why not "count()"?
# unique_sports_winter = athlete_events[athlete_events['Season'] == 'Winter'].groupby(['Year']).Sport.nunique()

# fig, axs = plt.subplots(1,2, figsize=[35,8])

# axs[0].title.set_text('Summer')
# axs[0].set_xticks([i for i in range(1896, 2018, 4)])
# axs[0].bar(unique_sports_summer.index, unique_sports_summer)

# axs[1].title.set_text('Winter')
# axs[1].set_xticks([i for i in range(1896, 2018, 4)])
# axs[1].bar(unique_sports_winter.index, unique_sports_winter)
# fig.show()

# unique_sports_summer.index


# Interesting anomalies: winter games before 1920 / two "gaps" / winter 92/94
# Interesting trends: addition of new sports for summer/winter / amount of sports in winter vs summer olympics


# group by multiple columns
# amount of events per year
df = df.groupby(['Year', 'Sport']).count()
#print(df)
# df.index
# print(df.index.names)
# print(df.index.levels)
# print(df.index.levels[0])


# The same, but for events using multi-index
new_df = df.set_index(['Year', 'Season'])
new_df.sort_index(inplace=True)
new_df

unique_events = new_df.groupby(level=['Year', 'Season']).Event.nunique()
unique_events.index
unique_events.index.levels
unique_events.index.levels[0]
# print(unique_events)

# easily display on single chart
# unique_events.plot.bar(figsize=[35,8])

# print(len(unique_events[:, 'Summer']))
# print(len(unique_events.index.levels[0]))


# two charts
# fig, axs = plt.subplots(1,2, figsize=[35,8])
# axs[0].title.set_text('Summer')
# axs[0].set_xticks([i for i in range(1896, 2018, 4)])
# axs[0].bar(unique_events.index.levels[0], unique_events[:, 'Summer'].reindex(unique_events.index.levels[0]))

# axs[1].title.set_text('Winter')
# axs[1].set_xticks([i for i in range(1896, 2018, 4)])
# axs[1].bar(unique_events.index.levels[0], unique_events[:, 'Winter'].reindex(unique_events.index.levels[0]))
# fig.show()

# same chart, different color + more beautiful formatting
fig, ax = plt.subplots(figsize=[35,8])
ax.set_xticks([i for i in range(1896, 2018, 4)])
ax.title.set_text('Olympic events per year')
ax.title.set_fontsize(30)
ax.bar(unique_events.index.levels[0], unique_events[:, 'Summer'].reindex(unique_events.index.levels[0]))
ax.bar(unique_events.index.levels[0], unique_events[:, 'Winter'].reindex(unique_events.index.levels[0]))
ax.legend(['Summer', 'Winter'], loc ="upper left", fontsize=15)
fig.show()

# %% [markdown]
# ### Athletes per Olympic games

# %%
athletes_by_year = athlete_events.groupby(['Year']).Name.nunique()
# fig, ax = plt.subplots(figsize=[20,8])
# ax.set_xticks([i for i in range(1886, 2020, 4)])
# ax.bar(athletes_by_year.index, athletes_by_year)

israeli_athlets = athlete_events[athlete_events['Team'] == 'Israel'].groupby(['Year']).Name.nunique()
# israeli_athlets
fig, ax = plt.subplots(figsize=[20,8])
ax.set_xticks([i for i in range(1886, 2020, 4)])
ax.bar(israeli_athlets.index, israeli_athlets)

# all the sports israelis participate in
# set(athlete_events[athlete_events['Team'] == 'Israel']['Sport'])

israeli_athlets = athlete_events[(athlete_events['Team'] == 'Israel') & (athlete_events['Sport'] == 'Judo')].groupby(['Year']).Name.nunique()
israeli_athlets

# %%
#  How many medals Israeli athlets won very year?
athlete_events[athlete_events['Team'] == 'Israel'].groupby(['Year','Medal']).count().ID

# average weight of male Tenis players (year over year)
# df1 = athlete_events.dropna(subset=['Weight'])
# filtered_df1 = df1[(athlete_events['Sport'] == 'Tennis') & (athlete_events['Sex']=='M')]
# filtered_df1.groupby('Year')['Weight'].mean()
tennis_weights_df = athlete_events.dropna(subset=['Weight'])[(athlete_events['Sport'] == 'Tennis') & (athlete_events['Sex']=='M')].groupby('Year')['Weight'].mean()
print(tennis_weights_df)
gymnastics_weights_df = athlete_events.dropna(subset=['Weight'])[(athlete_events['Sport'] == 'Gymnastics') & (athlete_events['Sex']=='M')].groupby('Year')['Weight'].mean()

tennis_weights_df.plot(figsize=[12,8])
gymnastics_weights_df.plot(figsize=[12,8])
plt.legend(['Tennis', 'Gymnastics'], loc='upper right')

# %%
athlete_events[(athlete_events['Year'] == 1920) & (athlete_events['Sport'] == 'Tennis')].isna().sum()

# %% [markdown]
# ## Diamonds dataset

# %%
diamonds=sns.load_dataset('diamonds')
# diamonds

# classic skewed distribution
# 
# diamonds.price.hist(bins=50,figsize=[12,8])

# multimodal distribution
# diamonds.carat.hist(bins=100, figsize=[12,8])

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds = sns.load_dataset('diamonds')

# %%
sns.displot(data=diamonds, x='carat', height=15, aspect=2.5)

# %%
sns.displot(data=diamonds, x='price', height=15, aspect=2.5)

# %%
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 10.7,10.27
sns.boxplot(data=diamonds, y='price', x='clarity')

# %% [markdown]
# ## Importing from SQL

# %%
# Example python program to read data from a PostgreSQL table

# and load into a pandas DataFrame

import psycopg2

import pandas as pds

from sqlalchemy import create_engine

 

# Create an engine instance

alchemyEngine   = create_engine('postgresql+psycopg2://deeptalk:@127.0.0.1', pool_recycle=3600);

 

# Connect to PostgreSQL server

dbConnection    = alchemyEngine.connect();

 

# Read data from PostgreSQL database table and load into a DataFrame instance

dataFrame       = pds.read_sql("select * from \"auth_user\"", dbConnection);

dataFrame


# Close the database connection

dbConnection.close();
